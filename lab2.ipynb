# %% [markdown]
# ![Black%20and%20White%20Math%20Pattern%20General%20LinkedIn%20Banner.png](attachment:Black%20and%20White%20Math%20Pattern%20General%20LinkedIn%20Banner.png)

# %% [markdown]
# # JUPYTER NOTEBOOK - PYTHON - WORKSHOP
# ## 2021 - 04

# %% [markdown]
# # Referencias
#
# https://github.com/jaatriana/GGMUV-JUPYTER-WORKSHOP

# %% [markdown]
# $$ \Large w = \frac{w_{masa\ de\ agua\ en\ el\ suelo}} {w_{masa\ de\ suelo\ seco}} = 3.2$$

# %%
w = 3.2
x = 10

# %%
slope = w*x

# %%
print(slope)
# Out:
# 32.0

# %% [markdown]
# ## 2.3 PROCEDIMIENTO

# %% [markdown]
# # # 2.1 CÁLCULOS
#
# 1. Calcular la masa de humedad $M_2 - M_3$
# 2. Calcular la masa de suelo seco

# %% [markdown]
# | Item | No 1 | No 2 | No 3 |
# | :---: | :---: | :---: | :---: |
# | Muestra | 42 | 51 | 34 |
#
# <div class="footer">
#    <p>Copyright ACME Incorporated ©2016</p>
# </div>
#
# asdasd

# %%
from math import sin, cos, tan, pi
gamma =21 # densidad de una arena
H =3      #m - altura del muro 
phi = 30
c = 0
sigma = 1/2*gamma*H
k = 1 -sin(phi)
#tau = c + sigma*tan(phi)

# %% [markdown]
# $$ Empuje = 1/2 \cdot \gamma \cdot H $$

# %%
sigma = 1/2*gamma*H #Este es el empuje del suelo

# %%
print('la variable a es = ',a)
print('el empuje es = ',empuje)
print('K es = ',k)
# Out:
# la variable a es =  10
# el empuje es =  31.5
# K es =  1.9880316240928617
